# %%
import sympy as sp

x = sp.symbols('x')

# %%
x , n = sp.symbols('x n')
f = x**n
display(f)
# Out:
# x**n

# %%
h = sp.exp(x)
display(h)
# Out:
# exp(x)

# %%
x = sp.Symbol('x')
x = sp.Lambda(x, x**2)
display(x)
display(x(3))
# Out:
# Lambda(x, x**2)
# 9
